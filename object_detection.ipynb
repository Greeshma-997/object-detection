# %% [markdown]
# <a href="https://colab.research.google.com/github/Greeshma-997/object-detection/blob/main/object_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics opencv-python

from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# Load a pre-trained YOLOv8 model
model = YOLO("yolov8n.pt")  # 'n' version is lightweight; use 'yolov8s.pt' for better accuracy

# Function to detect objects in an image
def detect_objects(image_path):
    # Load image
    img = cv2.imread(image_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB for proper display

    # Run object detection
    results = model(image_path)

    # Plot the detection results
    results[0].show()  # Displays the image with bounding boxes

    # Save output image with bounding boxes
    output_path = "detected_objects.jpg"
    results[0].save(output_path)
    print(f"Detection results saved to {output_path}")

# Test with a user-provided image
image_path = "/content/image.jpg"  # Change this to your image file path
detect_objects(image_path)
# Out:
# ...
#
# image 1/1 /content/image.jpg: 640x640 1 bench, 1 chair, 1 toilet, 2 tvs, 1 keyboard, 1 clock, 214.7ms
# Speed: 3.8ms preprocess, 214.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=225x225>
# Detection results saved to detected_objects.jpg
